# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Qwen/Qwen2.5-1.5B-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "Is keeping gold in locker is safe or not ?"
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": prompt}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=512, temperature=0.8,top_p=0.8,
)
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
print(response)
# Out:
# The safety of storing gold depends on various factors such as the quality and reliability of the storage facility, the security measures taken, and whether there's an insurance policy in place.
#
# 1. **Quality and Reliability of Storage Facility**: If you choose to store your gold at a reputable vault or secure location, it can be quite safe. Many banks offer safe deposit boxes that are highly secure and insured against theft and loss.
#
# 2. **Security Measures**: A good vault should have robust security systems including electronic locks, surveillance cameras, and access controls. These measures significantly reduce the risk of unauthorized access.
#
# 3. **Insurance**: Having insurance coverage for your stored assets adds another layer of protection. Insurance companies typically cover losses due to theft, fire, or other unforeseen events, which can help mitigate financial risks associated with losing your gold.
#
# 4. **Professional Handling**: Professional custodians will handle your gold with care and ensure its safekeeping. They may also provide additional services like tracking, reporting, and tax compliance.
#
# 5. **Legal and Regulatory Compliance**: Ensure that the storage location complies with all relevant laws and regulations regarding precious metals storage.
#
# 6. **Market Volatility**: While physically holding gold reduces volatility compared to owning stocks or bonds, market fluctuations still affect prices and demand. The value of physical gold could depreciate if the price of gold falls below the cost of storing it (i.e., when it becomes uneconomical).
#
# In summary, while storing gold in a secure, well-managed location with appropriate insurance and professional oversight can make it relatively safer than keeping it under personal custody, it’s important to carefully consider the specific risks involved before making any decision.
